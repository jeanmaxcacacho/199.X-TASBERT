# %% [markdown]
# <a href="https://colab.research.google.com/github/jeanmaxcacacho/199.X-TASBERT/blob/main/TAS_BERT_replicate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TODOs for this Notebook
#
#
# *   Instantiate the base TAS-BERT model.
# *   Load [*our sample data*](https://www.kaggle.com/datasets/asaniczka/reddit-on-israel-palestine-daily-updated), and perform inference on *complex inputs.*

# %%
# init
print("hello world")
# Out:
# hello world
